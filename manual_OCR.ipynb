# %%
# !pip install "paddleocr>=2.0.1"
# Out:
# ...
#   Using cached paddleocr-2.6.1.2-py3-none-any.whl (440 kB)
# ...
#   Using cached opencv_contrib_python-4.7.0.68-cp37-abi3-win_amd64.whl (44.9 MB)
# ...
#   Using cached premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# ...
#   Using cached pdf2docx-0.5.6-py3-none-any.whl (148 kB)
# ...
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# ...
#   Using cached lxml-4.9.2-cp310-cp310-win_amd64.whl (3.8 MB)
# ...
#   Using cached fire-0.5.0.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# ...
#   Using cached visualdl-2.5.0-py3-none-any.whl (6.3 MB)
# ...
#   Using cached attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# ...
#   Using cached python-docx-0.8.11.tar.gz (5.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
from paddleocr import PaddleOCR,draw_ocr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\chara\OneDrive\Documents\receiptcheck\manual_OCR.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/chara/OneDrive/Documents/receiptcheck/manual_OCR.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from paddleocr import PaddleOCR,draw_ocr
#
# ModuleNotFoundError: No module named 'paddleocr'
