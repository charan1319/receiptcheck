# %%
from PIL import Image

# %%
# !pip install "paddleocr>=2.0.1" --user
# Out:
# Requirement already satisfied: paddleocr>=2.0.1 in c:\users\amans\appdata\roaming\python\python37\site-packages (2.6.1.2)
# Requirement already satisfied: pyclipper in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (1.3.0.post4)
# Requirement already satisfied: python-docx in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (0.8.11)
# Requirement already satisfied: scikit-image in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (0.19.3)
# Requirement already satisfied: PyMuPDF<1.21.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (1.20.2)
# Requirement already satisfied: lxml in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (4.9.2)
# Requirement already satisfied: shapely in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (2.0.0)
# Requirement already satisfied: pdf2docx in c:\users\amans\appdata\roaming\python\python37\site-packages (from paddleocr>=2.0.1) (0.5.6)
# Requirement already satisfied: premailer in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (3.10.0)
# Requirement already satisfied: opencv-python in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (4.7.0.68)
# Requirement already satisfied: rapidfuzz in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (2.13.7)
# Requirement already satisfied: lmdb in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (1.4.0)
# Requirement already satisfied: cython in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (0.29.33)
# Requirement already satisfied: fire>=0.3.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from paddleocr>=2.0.1) (0.5.0)
# Requirement already satisfied: openpyxl in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (3.0.10)
# Requirement already satisfied: beautifulsoup4 in c:\users\amans\appdata\roaming\python\python37\site-packages (from paddleocr>=2.0.1) (4.11.1)
# Requirement already satisfied: attrdict in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (2.0.1)
# Requirement already satisfied: imgaug in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (0.4.0)
# Requirement already satisfied: visualdl in c:\users\amans\appdata\roaming\python\python37\site-packages (from paddleocr>=2.0.1) (2.5.0)
# Requirement already satisfied: numpy in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (1.21.6)
# Requirement already satisfied: opencv-contrib-python in c:\users\amans\appdata\roaming\python\python37\site-packages (from paddleocr>=2.0.1) (4.7.0.68)
# Requirement already satisfied: fonttools>=4.24.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (4.38.0)
# Requirement already satisfied: tqdm in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddleocr>=2.0.1) (4.64.1)
# Requirement already satisfied: six in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from fire>=0.3.0->paddleocr>=2.0.1) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from fire>=0.3.0->paddleocr>=2.0.1) (2.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from beautifulsoup4->paddleocr>=2.0.1) (2.3.2.post1)
# Requirement already satisfied: scipy in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from imgaug->paddleocr>=2.0.1) (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from imgaug->paddleocr>=2.0.1) (3.5.3)
# Requirement already satisfied: imageio in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from imgaug->paddleocr>=2.0.1) (2.25.0)
# Requirement already satisfied: Pillow in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from imgaug->paddleocr>=2.0.1) (9.4.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (2.6.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (23.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from scikit-image->paddleocr>=2.0.1) (2021.11.2)
# Requirement already satisfied: et-xmlfile in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from openpyxl->paddleocr>=2.0.1) (1.1.0)
# Requirement already satisfied: requests in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from premailer->paddleocr>=2.0.1) (2.28.2)
# Requirement already satisfied: cssselect in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from premailer->paddleocr>=2.0.1) (1.2.0)
# Requirement already satisfied: cssutils in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from premailer->paddleocr>=2.0.1) (2.6.0)
# Requirement already satisfied: cachetools in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from premailer->paddleocr>=2.0.1) (5.3.0)
# Requirement already satisfied: colorama in c:\users\amans\appdata\roaming\python\python37\site-packages (from tqdm->paddleocr>=2.0.1) (0.4.1)
# Requirement already satisfied: bce-python-sdk in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (0.8.74)
# Requirement already satisfied: Flask-Babel>=3.0.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (3.0.0)
# Requirement already satisfied: gradio in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (3.16.2)
# Requirement already satisfied: onnx>=1.6.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (1.13.0)
# Requirement already satisfied: rarfile in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from visualdl->paddleocr>=2.0.1) (4.0)
# Requirement already satisfied: tritonclient[all] in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from visualdl->paddleocr>=2.0.1) (2.22.0)
# Requirement already satisfied: multiprocess in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (0.70.14)
# Requirement already satisfied: pandas in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from visualdl->paddleocr>=2.0.1) (1.3.5)
# Requirement already satisfied: x2paddle in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (1.4.0)
# Requirement already satisfied: flask>=1.1.1 in c:\users\amans\appdata\roaming\python\python37\site-packages (from visualdl->paddleocr>=2.0.1) (2.2.2)
# Requirement already satisfied: psutil in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from visualdl->paddleocr>=2.0.1) (5.9.4)
# Requirement already satisfied: protobuf>=3.11.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from visualdl->paddleocr>=2.0.1) (3.20.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\amans\appdata\roaming\python\python37\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (8.1.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from flask>=1.1.1->visualdl->paddleocr>=2.0.1) (6.0.0)
# Requirement already satisfied: Babel<3.0.0,>=2.11.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2.11.0)
# Requirement already satisfied: pytz<2023.0,>=2022.7 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from Flask-Babel>=3.0.0->visualdl->paddleocr>=2.0.1) (2022.7.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from onnx>=1.6.0->visualdl->paddleocr>=2.0.1) (4.4.0)
# Requirement already satisfied: pycryptodome>=3.8.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from bce-python-sdk->visualdl->paddleocr>=2.0.1) (3.17)
# Requirement already satisfied: future>=0.6.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from bce-python-sdk->visualdl->paddleocr>=2.0.1) (0.18.3)
# Requirement already satisfied: httpx in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (0.23.3)
# Requirement already satisfied: websockets>=10.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (10.4)
# Requirement already satisfied: aiofiles in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (22.1.0)
# Requirement already satisfied: uvicorn in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (0.20.0)
# Requirement already satisfied: pydub in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (0.25.1)
# Requirement already satisfied: pydantic in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (1.10.4)
# Requirement already satisfied: fastapi in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (0.89.1)
# Requirement already satisfied: fsspec in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (2023.1.0)
# Requirement already satisfied: markupsafe in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (2.1.2)
# Requirement already satisfied: ffmpy in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (0.3.0)
# Requirement already satisfied: altair>=4.2.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (4.2.2)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (2.1.0)
# Requirement already satisfied: pyyaml in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (6.0)
# Requirement already satisfied: aiohttp in c:\users\amans\appdata\roaming\python\python37\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (3.8.3)
# Requirement already satisfied: orjson in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (3.8.5)
# Requirement already satisfied: python-multipart in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gradio->visualdl->paddleocr>=2.0.1) (0.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from matplotlib->imgaug->paddleocr>=2.0.1) (0.11.0)
# Requirement already satisfied: dill>=0.3.6 in c:\users\amans\appdata\roaming\python\python37\site-packages (from multiprocess->visualdl->paddleocr>=2.0.1) (0.3.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests->premailer->paddleocr>=2.0.1) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amans\appdata\roaming\python\python37\site-packages (from requests->premailer->paddleocr>=2.0.1) (2.1.1)
# Requirement already satisfied: python-rapidjson>=0.9.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from tritonclient[all]->visualdl->paddleocr>=2.0.1) (1.9)
# Requirement already satisfied: grpcio==1.41.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from tritonclient[all]->visualdl->paddleocr>=2.0.1) (1.41.0)
# Requirement already satisfied: geventhttpclient>=1.4.4 in c:\users\amans\appdata\roaming\python\python37\site-packages (from tritonclient[all]->visualdl->paddleocr>=2.0.1) (2.0.8)
# Requirement already satisfied: sympy in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from x2paddle->visualdl->paddleocr>=2.0.1) (1.10.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from altair>=4.2.0->gradio->visualdl->paddleocr>=2.0.1) (4.17.3)
# Requirement already satisfied: entrypoints in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from altair>=4.2.0->gradio->visualdl->paddleocr>=2.0.1) (0.4)
# Requirement already satisfied: toolz in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from altair>=4.2.0->gradio->visualdl->paddleocr>=2.0.1) (0.12.0)
# Requirement already satisfied: gevent>=0.13 in c:\users\amans\appdata\roaming\python\python37\site-packages (from geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (22.10.2)
# Requirement already satisfied: brotli in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (1.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from importlib-metadata>=3.6.0->flask>=1.1.1->visualdl->paddleocr>=2.0.1) (3.12.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (1.8.2)
# Requirement already satisfied: asynctest==0.13.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from aiohttp->gradio->visualdl->paddleocr>=2.0.1) (22.2.0)
# Requirement already satisfied: starlette==0.22.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from fastapi->gradio->visualdl->paddleocr>=2.0.1) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from starlette==0.22.0->fastapi->gradio->visualdl->paddleocr>=2.0.1) (3.6.2)
# Requirement already satisfied: sniffio in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from httpx->gradio->visualdl->paddleocr>=2.0.1) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from httpx->gradio->visualdl->paddleocr>=2.0.1) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from httpx->gradio->visualdl->paddleocr>=2.0.1) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\amans\appdata\roaming\python\python37\site-packages (from markdown-it-py[linkify,plugins]->gradio->visualdl->paddleocr>=2.0.1) (0.1.2)
# Requirement already satisfied: linkify-it-py~=1.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from markdown-it-py[linkify,plugins]->gradio->visualdl->paddleocr>=2.0.1) (1.0.3)
# Requirement already satisfied: mdit-py-plugins in c:\users\amans\appdata\roaming\python\python37\site-packages (from markdown-it-py[linkify,plugins]->gradio->visualdl->paddleocr>=2.0.1) (0.3.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from sympy->x2paddle->visualdl->paddleocr>=2.0.1) (1.2.1)
# Requirement already satisfied: h11>=0.8 in c:\users\amans\appdata\roaming\python\python37\site-packages (from uvicorn->gradio->visualdl->paddleocr>=2.0.1) (0.14.0)
# Requirement already satisfied: greenlet>=2.0.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from gevent>=0.13->geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (2.0.2)
# Requirement already satisfied: setuptools in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gevent>=0.13->geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (47.1.0)
# Requirement already satisfied: zope.event in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gevent>=0.13->geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (4.6)
# Requirement already satisfied: zope.interface in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from gevent>=0.13->geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (5.5.2)
# Requirement already satisfied: cffi>=1.12.2 in c:\users\amans\appdata\roaming\python\python37\site-packages (from gevent>=0.13->geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (1.15.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\amans\appdata\roaming\python\python37\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl->paddleocr>=2.0.1) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl->paddleocr>=2.0.1) (0.19.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->visualdl->paddleocr>=2.0.1) (1.3.10)
# Requirement already satisfied: uc-micro-py in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from linkify-it-py~=1.0->markdown-it-py[linkify,plugins]->gradio->visualdl->paddleocr>=2.0.1) (1.0.1)
# Requirement already satisfied: pycparser in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from cffi>=1.12.2->gevent>=0.13->geventhttpclient>=1.4.4->tritonclient[all]->visualdl->paddleocr>=2.0.1) (2.21)

# %%
# !pip install paddlepaddle --user
# Out:
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.4.1-cp37-cp37m-win_amd64.whl (68.1 MB)
#      --------------------------------------- 68.1/68.1 MB 12.1 MB/s eta 0:00:00
# Collecting paddle-bfloat==0.1.7
#   Downloading paddle_bfloat-0.1.7-cp37-cp37m-win_amd64.whl (40 kB)
#      ---------------------------------------- 40.6/40.6 kB 1.9 MB/s eta 0:00:00
# Collecting opt-einsum==3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (2.28.2)
# Requirement already satisfied: Pillow in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (9.4.0)
# Requirement already satisfied: numpy>=1.13 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (1.21.6)
# Collecting protobuf<=3.20.0,>=3.1.0
#   Using cached protobuf-3.20.0-cp37-cp37m-win_amd64.whl (905 kB)
# Requirement already satisfied: six in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (1.16.0)
# Requirement already satisfied: decorator in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (5.1.1)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests>=2.20.0->paddlepaddle) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests>=2.20.0->paddlepaddle) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amans\appdata\roaming\python\python37\site-packages (from requests>=2.20.0->paddlepaddle) (2.1.1)
# Installing collected packages: paddle-bfloat, protobuf, opt-einsum, astor, paddlepaddle
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddle-bfloat-0.1.7 paddlepaddle-2.4.1 protobuf-3.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnx 1.13.0 requires protobuf<4,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# Collecting paddlepaddle
#   Downloading paddlepaddle-2.4.1-cp37-cp37m-win_amd64.whl (68.1 MB)
#      ---------------------------------------- 68.1/68.1 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (1.21.6)
# Collecting opt-einsum==3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB ? eta 0:00:00
# Requirement already satisfied: decorator in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (5.1.1)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (2.28.2)
# Collecting protobuf<=3.20.0,>=3.1.0
#   Downloading protobuf-3.20.0-cp37-cp37m-win_amd64.whl (905 kB)
#      ------------------------------------- 905.1/905.1 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (9.4.0)
# Requirement already satisfied: six in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from paddlepaddle) (1.16.0)
# Collecting paddle-bfloat==0.1.7
#   Using cached paddle_bfloat-0.1.7-cp37-cp37m-win_amd64.whl (40 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amans\appdata\roaming\python\python37\site-packages (from requests>=2.20.0->paddlepaddle) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests>=2.20.0->paddlepaddle) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages (from requests>=2.20.0->paddlepaddle) (3.4)
# Installing collected packages: paddle-bfloat, protobuf, opt-einsum, astor, paddlepaddle
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed astor-0.8.1 opt-einsum-3.3.0 paddle-bfloat-0.1.7 paddlepaddle-2.4.1 protobuf-3.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnx 1.13.0 requires protobuf<4,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.

# %%
from paddleocr import PaddleOCR,draw_ocr

# %%
ocr = PaddleOCR(lang='en') # need to run only once to download and load model into memory
img_path = 'Bill.com/img/00d0100894168.jpg'
result = ocr.ocr(img_path, cls=False)
for idx in range(len(result)):
    res = result[idx]
    for line in res:
        print(line)
result = result[0]
# print("RESULT[0]", result)
image = Image.open(img_path).convert('RGB') 
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]
scores = [line[1][1] for line in result]
im_show = draw_ocr(image, boxes, txts, scores, font_path='/path/to/PaddleOCR/doc/fonts/simfang.ttf')
im_show = Image.fromarray(im_show)
im_show.save('result.jpg')
print("DONE")
# Out:
# [2023/01/28 20:45:57] ppocr DEBUG: Namespace(alpha=1.0, benchmark=False, beta=1.0, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='C:\\Users\\amans/.paddleocr/whl\\cls\\ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='C:\\Users\\amans/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv3', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='C:\\Users\\amans\\AppData\\Roaming\\Python\\Python37\\site-packages\\paddleocr\\ppocr\\utils\\en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='C:\\Users\\amans/.paddleocr/whl\\rec\\en\\en_PP-OCRv3_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=False, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [2023/01/28 20:45:59] ppocr DEBUG: dt_boxes num : 77, elapse : 0.717076301574707
# [2023/01/28 20:46:14] ppocr DEBUG: rec_res num  : 77, elapse : 15.222140550613403
# [[[1535.0, 446.0], [2509.0, 431.0], [2511.0, 533.0], [1537.0, 549.0]], ('AEON CO. (M) BHD (126926-H)', 0.9923710227012634)]
# [[[1498.0, 541.0], [2546.0, 533.0], [2547.0, 636.0], [1499.0, 643.0]], ('3RD FLR, AEON TAMAN MALURI SC', 0.9942921996116638)]
# [[[1565.0, 643.0], [2436.0, 635.0], [2437.0, 738.0], [1566.0, 746.0]], (' JLn JeJaKa, TaMan MaLUrI', 0.7233112454414368)]
# [[[1543.0, 745.0], [2473.0, 745.0], [2473.0, 848.0], [1543.0, 848.0]], ('CHERAS, 55100 KUALA LUMPUR', 0.9957513213157654)]
# [[[1639.0, 848.0], [2407.0, 848.0], [2407.0, 950.0], [1639.0, 950.0]], ('GST ID : 002017394688', 0.9964098930358887)]
# [[[1789.0, 934.0], [2304.0, 951.0], [2301.0, 1054.0], [1785.0, 1037.0]], ('SHOPPING HOURS', 0.987628161907196)]
# [[[1499.0, 5912.0], [2458.0, 5912.0], [2458.0, 6007.0], [1499.0, 6007.0]], ('EXCLUSIVE FOR AEON MEMBERS:', 0.9990063905715942)]
# [[[1314.0, 6103.0], [2569.0, 6095.0], [2569.0, 6197.0], [1314.0, 6205.0]], ('We tove To Hear Your Feedback Visit', 0.9692461490631104)]
# [[[1240.0, 6205.0], [2635.0, 6197.0], [2636.0, 6300.0], [1241.0, 6307.0]], ('www.survaynonkey.com/r/AEONCSIS (store)', 0.9491738677024841)]
# [[[1210.0, 6307.0], [2627.0, 6292.0], [2629.0, 6394.0], [1211.0, 6410.0]], ('/ www.Surveymonkey.com/r/AEONCSIM (mall)', 0.9397926330566406)]
# [[[1595.0, 6497.0], [2363.0, 6505.0], [2362.0, 6607.0], [1594.0, 6599.0]], ('Share Your Experience', 0.9754891991615295)]
# [[[1499.0, 6607.0], [2466.0, 6607.0], [2466.0, 6702.0], [1499.0, 6702.0]], ('*Get RM5 Aeon Gift Voucher*', 0.9973059892654419)]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22168\17969098.py in <module>
#      12 txts = [line[1][0] for line in result]
#      13 scores = [line[1][1] for line in result]
# ---> 14 im_show = draw_ocr(image, boxes, txts, scores, font_path='/path/to/PaddleOCR/doc/fonts/simfang.ttf')
#      15 im_show = Image.fromarray(im_show)
#      16 im_show.save('result.jpg')
#
# ~\AppData\Roaming\Python\Python37\site-packages\paddleocr\tools\infer\utility.py in draw_ocr(image, boxes, txts, scores, drop_score, font_path)
#     393             img_w=600,
#     394             threshold=drop_score,
# --> 395             font_path=font_path)
#     396         img = np.concatenate([np.array(img), np.array(txt_img)], axis=1)
#     397         return img
#
# ~\AppData\Roaming\Python\Python37\site-packages\paddleocr\tools\infer\utility.py in text_visual(texts, scores, img_h, img_w, threshold, font_path)
#     531     font_size = 20
#     532     txt_color = (0, 0, 0)
# --> 533     font = ImageFont.truetype(font_path, font_size, encoding="utf-8")
#     534
#     535     gap = font_size + 5
#
# c:\Users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages\PIL\ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#    1006
#    1007     try:
# -> 1008         return freetype(font)
#    1009     except OSError:
#    1010         if not is_path(font):
#
# c:\Users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages\PIL\ImageFont.py in freetype(font)
#    1003
#    1004     def freetype(font):
# -> 1005         return FreeTypeFont(font, size, index, encoding, layout_engine)
#    1006
#    1007     try:
#
# c:\Users\amans\.pyenv\pyenv-win\versions\3.7.9\lib\site-packages\PIL\ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     254                     return
#     255             self.font = core.getfont(
# --> 256                 font, size, index, encoding, layout_engine=layout_engine
#     257             )
#     258         else:
#
# OSError: cannot open resource

# %%
result = result[0]
print(result)
image = Image.open(img_path).convert('RGB')
print(line)
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]
scores = [line[1][1] for line in result]
im_show = draw_ocr(image, boxes, txts, scores, font_path='/path/to/PaddleOCR/doc/fonts/simfang.ttf')
im_show = Image.fromarray(im_show)
im_show.save('result.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22168\2868122538.py in <module>
# ----> 1 result = result[0]
#       2 print(result)
#       3 image = Image.open(img_path).convert('RGB')
#       4 print(line)
#       5 # boxes = [line[0] for line in result]
#
# TypeError: 'float' object is not subscriptable
