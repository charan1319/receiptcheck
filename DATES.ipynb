# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2 
import numpy as np
import pandas as pd
import torch
import re
import os

# %%
userData = pd.read_csv('Bill.com/Users.csv')

# %%
dir = 'Bill.com/ocr/'
for name in os.listdir(dir):
    if name.endswith(".csv"):
        # print(name)
        OCR_CSV = pd.read_csv(dir + '/' + name, names=["x1","y1","x2","y2","x3","y3","x4","y4","TEXT"], engine='python', on_bad_lines='skip')
        # print(OCR_CSV)
        
        OCR_CSV_STRING = OCR_CSV.to_string()
        date_re = "\d{2}[/-]\d{2}[,\s/-]\d+"
        dates = re.findall(date_re, OCR_CSV_STRING)
        
        if dates:
            print(name, dates, "True")
        else:
            print(name, dates, "False")
# Out:
# 00d0100894168.csv ['11/05/2018'] True
# 00d0102367243.csv ['18-06-2018'] True
# 00d0103738916.csv ['12-02-2018'] True
# 00d0106074517.csv ['30-04-18'] True
# 00d0106280922.csv ['15/01/2018'] True
# 00d0108922007.csv ['25/12/2018'] True
# 00d0114026522.csv ['13/01/2018'] True
# 00d0114666542.csv ['01-06-2018'] True
# 00d0115214912.csv ['10/05/2017'] True
# 00d0116292534.csv ['07/07/17'] True
# 00d0116788763.csv ['11-04-18'] True
# 00d0118393124.csv ['27/02/2018'] True
# 00d0121860229.csv ['03-05-18'] True
# 00d0121880972.csv ['13/03/2018'] True
# 00d0123031653.csv ['10/02/2017', '10/02/2017'] True
# 00d0124895452.csv ['20/03/2018'] True
# 00d0128862298.csv ['05-05-18'] True
# 00d0130065999.csv ['18-04-06', '06/04/18'] True
# 00d0139330423.csv ['28-05-2018', '28-05-2018'] True
# 00d0139642641.csv [] False
# 00d0142736377.csv ['13-06-2018', '13-06-2018'] True
# 00d0145054354.csv ['11/12/2017'] True
# 00d0145695018.csv ['03/08/2017', '03/08/2017'] True
# 00d0147095939.csv ['13/10/2017'] True
# 00d0147748424.csv [] False
# 00d0150882989.csv ['07-02-18'] True
# 00d0152915085.csv ['04-06-2018', '04-06-2018'] True
# 00d0159517738.csv ['14-08-17'] True
# 00d0159988592.csv [] False
# 00d0164203891.csv ['10/06/2018'] True
# 00d0164592408.csv ['05-03-2018'] True
# 00d0165073570.csv ['27/07/17'] True
# 00d0166687964.csv ['31/01/2018'] True
# 00d0167381962.csv ['22/03/2018'] True
# 00d0171220341.csv ['11/01/2018'] True
# 00d0174068255.csv ['10/10/2017', '10/10/2017'] True
# 00d0174270341.csv ['21/05/2018', '00-13-1300'] True
# 00d0177909385.csv ['15/01/2018'] True
# 00d0178057064.csv ['18/06/20', '20/06/2018', '20/06/2018'] True
# 00d0178282813.csv ['28/06/2018'] True
# 00d0178827407.csv ['31-03-2018', '31-03-2018'] True
# 00d0179226173.csv ['11-06-2018'] True
# 00d0180967427.csv ['22-06-2017'] True
# 00d0182384739.csv ['24/08/2017', '24/08/2017'] True
# 00d0183401385.csv ['10/03/2018'] True
# 00d0184132278.csv ['02/05/2018'] True
# 00d0185599105.csv ['25-01-16'] True
# 00d0186887844.csv ['23-03-18'] True
# 00d0188523936.csv ['10-05-17'] True
# 00d0408017404.csv ['15/06/2017'] True
# 00d0408489357.csv [] False
# 00d0411132243.csv ['26/10/2017', '26/10/2017'] True
# 00d0411843053.csv ['09-04-2018'] True
# 00d0414196980.csv ['14-03-2018'] True
# 00d0415751725.csv ['25/06/18', '25/06/18', '25/06/18'] True
# 00d0416161702.csv ['17-12-28', '12/28/2017'] True
# 00d0417300467.csv ['02/03/2018'] True
# 00d0419719085.csv [] False
# 00d0422368687.csv ['12/05/2018'] True
# 00d0423671916.csv ['19/09/2017', '19/09/2017'] True
# 00d0426803895.csv ['19/03/2018'] True
# 00d0432757654.csv ['13/04/2018'] True
# 00d0435331752.csv ['03/05/2018'] True
# 00d0437873955.csv ['10-03-2018', '11-03-2018'] True
# 00d0439076290.csv ['32-51-71', '22-04-16'] True
# 00d0443302756.csv ['05-05-2018'] True
# 00d0443910003.csv ['05/03/18', '31/05/18'] True
# 00d0447521528.csv ['06-04-18'] True
# 00d0448828100.csv ['15/03/2018'] True
# 00d0449236994.csv ['10/08/2017', '10/08/2017'] True
# 00d0449498451.csv ['18/03/2018', '00-13-1300'] True
# 00d0450998902.csv ['00-88-5200'] True
# 00d0452553939.csv [] False
# 00d0453226524.csv [] False
# 00d0453489586.csv ['22/04/2018'] True
# 00d0453904564.csv ['19/10/2017', '19/10/2017'] True
# 00d0457456115.csv ['14-02-2018', '14-02-2018'] True
# 00d0458708415.csv ['25/08/2017', '25/08/2017'] True
# 00d0459172796.csv ['05/09/2017', '05/09/2017'] True
# 00d0463604996.csv [] False
# 00d0464021737.csv ['06/04/17'] True
# 00d0464742744.csv ['20/09/2017'] True
# 00d0471112949.csv ['02/06/18', '02/06/18'] True
# 00d0471481845.csv ['41-51/2', '24/72\n15', '19-04-18'] True
# 00d0471591245.csv ['15/04/18', '15/04/18'] True
# 00d0472127340.csv ['15-06-18'] True
# 00d0472780579.csv ['04-04-2018'] True
# 00d0472913563.csv ['07/05/2018'] True
# 00d0474678678.csv ['19/05/18'] True
# 00d0477553790.csv ['15/07/2017'] True
# 00d0483826961.csv ['30/03/2018'] True
# 00d0484705589.csv ['03/07/2018'] True
# 00d0484942812.csv ['04/12/2017'] True
# 00d0485748096.csv ['03-02-16'] True
# 00d0485758378.csv ['02/01/2018'] True
# 00d0485821436.csv ['05/01/2018'] True
# 00d0487139957.csv ['11-06-2018', '11-06-2018'] True
# 00d0489061247.csv ['14/05/2018'] True
# 00d0490682838.csv ['06/07/2017'] True
# 00d0495694280.csv ['24/07/2017'] True
# 00d0497274391.csv ['06/09/2017'] True
# 00d0500564944.csv ['27-04-18'] True
# 00d0500910371.csv ['18-03-18', '18-03-18'] True
# 00d0502129574.csv ['22/04/2018'] True
# 00d0504003816.csv ['12-06-2018'] True
# 00d0504725741.csv ['04-18/084227', '06/02/2018'] True
# 00d0507143553.csv ['01/06/2018'] True
# 00d0508747957.csv ['03/04/2018'] True
# 00d0510871247.csv ['03/09/2017', '03/09/2017'] True
# 00d0511840834.csv ['18-10-17'] True
# 00d0513207673.csv ['20/03/2018'] True
# 00d0523654121.csv ['03-02-18'] True
# 00d0524794165.csv ['10-05-17'] True
# 00d0527382713.csv ['02/01/2018'] True
# 00d0529128132.csv [] False
# 00d0530467663.csv ['24/05/18'] True
# 00d0530724847.csv ['19-03-2018'] True
# 00d0531848355.csv [] False
# 00d0532350198.csv ['09/03/2018'] True
# 00d0533588228.csv ['14/03/2018'] True
# 00d0537233731.csv ['13/06/2018'] True
# 00d0539072705.csv ['17/06/2018'] True
# 00d0541369548.csv ['13-02-2016'] True
# 00d0542157895.csv ['27/02/18', '31/05/18'] True
# 00d0542888628.csv ['24-01-16'] True
# 00d0543055869.csv ['18-01-05'] True
# 00d0543406251.csv ['12/08/2017'] True
# 00d0546591203.csv ['28/12/2017'] True
# 00d0547495073.csv ['18/06/2018', '18/06/2018'] True
# 00d0547632877.csv ['28-05-18'] True
# 00d0550391706.csv ['13-05-18'] True
# 00d0551541808.csv ['12-01-19'] True
# 00d0552375573.csv ['04/09/2017'] True
# 00d0552638268.csv ['40/20\n6', '07/01/18'] True
# 00d0553233477.csv ['16/02/2018'] True
# 00d0555910882.csv ['28/02/2018'] True
# 00d0556108338.csv [] False
# 00d0558270937.csv [] False
# 00d0564198512.csv ['03/06/2017'] True
# 00d0564199588.csv ['25/12/2017'] True
# 00d0568013096.csv ['02/03/2018'] True
# 00d0570374781.csv ['12/04/2018'] True
# 00d0572439292.csv ['26-03-18'] True
# 00d0574862056.csv ['26/03/18'] True
# 00d0576905492.csv [] False
# 00d0577470816.csv [] False
# 00d0581923422.csv ['14/04/2018', '14/04/2018'] True
# 00d0582681704.csv ['05/01/2018'] True
# 00d0582732557.csv ['25/09/2017'] True
# 00d0583684114.csv ['24/06/2018'] True
# 00d0585896483.csv ['27/07/2017', '27/07/2017'] True
# 00d0588374381.csv [] False
# 00d0594663786.csv ['01/05/16'] True
# 00d0595804986.csv ['30-06-16'] True
# 00d0599423844.csv ['27/03/2018'] True
# 00d0599930970.csv ['13-09-2017', '02-02\n41'] True
# 00d0600715913.csv ['29/06/2018'] True
# 00d0601744334.csv ['25/09/2017', '25/09/2017'] True
# 00d0602427476.csv [] False
# 00d0603631647.csv ['30/04/2017', '30/04/2017'] True
# 00d0606455264.csv ['28/02/2018'] True
# 00d0606540603.csv ['12/01/2018'] True
# 00d0607552804.csv ['10/10/2017'] True
# 00d0608126101.csv ['17/04/18'] True
# 00d0608566104.csv ['18/04/2017'] True
# 00d0610473999.csv ['17/01/2018'] True
# 00d0614628355.csv ['21-03-2018'] True
# 00d0616798510.csv ['05-05-17'] True
# 00d0617357249.csv ['27/05/2018'] True
# 00d0619690945.csv [] False
# 00d0622420051.csv ['12/06/2018'] True
# 00d0624439175.csv ['17-04-16'] True
# 00d0626463001.csv [] False
# 00d0627357411.csv ['23-33-53', '24-03-18'] True
# 00d0627737900.csv ['29/10/2017'] True
# 00d0628164309.csv [] False
# 00d0630325043.csv ['02/01/2018'] True
# 00d0632172733.csv ['09/06/2018', '09/06/2018'] True
# 00d0632354255.csv ['03-04-06', '11-22-31', '19-09-17'] True
# 00d0902256238.csv ['02-04-2018'] True
# 00d0904732199.csv ['00-88-6555'] True
# 00d0904741091.csv [] False
# 00d0910574175.csv ['24/05/2018'] True
# 00d0910676977.csv ['30/03/2018', '30/03/2018', '30/03/2018'] True
# 00d0910776987.csv ['03-05-18'] True
# 00d0911031443.csv ['10/10\n3', '10-04-2018', '00-22-2828'] True
# 00d0911267818.csv ['07-06-16'] True
# 00d0913770897.csv ['12/02/2018'] True
# 00d0914854329.csv [] False
# 00d0916006350.csv ['24/06/2018'] True
# 00d0916574976.csv ['22-52-62', '18-03-18'] True
# 00d0920231897.csv ['19/07/2017'] True
# 00d0920899195.csv [] False
# 00d0921867955.csv ['21-31/2', '19-04-18'] True
# 00d0922342206.csv ['04/03/2018'] True
# 00d0923796657.csv ['30/03/2017'] True
# 00d0924594862.csv ['15-07-18'] True
# 00d0928366034.csv ['16/05/01', '16/05/01'] True
# 00d0928411057.csv ['22/12/2017'] True
# 00d0929882897.csv ['17/09/2017', '17/09/2017'] True
# 00d0930697230.csv [] False
# 00d0935614053.csv ['27/03/2018'] True
# 00d0935702550.csv ['20/03/2018'] True
# 00d0942116852.csv ['14-01-2018'] True
# 00d0944155034.csv ['04-06-2018'] True
# 00d0944630849.csv ['23/03/2018', '23/03/2018'] True
# 00d0945045450.csv ['21-04-2018', '21-04-2018'] True
# 00d0945445352.csv ['25-03-18'] True
# 00d0948483091.csv ['21-31/2', '22-04-16'] True
# 00d0948775947.csv ['20/04/2018'] True
# 00d0950145735.csv ['05-06-2018', '05-06-2018'] True
# 00d0950629356.csv ['12/05/18', '12/05/18'] True
# 00d0951021760.csv [] False
# 00d0952509602.csv ['04/03/18'] True
# 00d0953772440.csv ['15/05/2017'] True
# 00d0954032591.csv [] False
# 00d0955195431.csv ['16/09/2017', '16/09/2017'] True
# 00d0958758313.csv [] False
# 00d0961798581.csv [] False
# 00d0963161084.csv ['23/04/2017'] True
# 00d0964499840.csv ['18/01/2018'] True
# 00d0965540723.csv ['25-04-18'] True
# 00d0968376605.csv ['12/13/2016'] True
# 00d0969391958.csv [] False
# 00d0970540567.csv [] False
# 00d0972867846.csv ['24-05-2018'] True
# 00d0973066652.csv ['11/01/2019'] True
# 00d0973462000.csv ['01/11/2017'] True
# 00d0975647472.csv ['23/10/2017', '23/10/2017'] True
# 00d0976342068.csv ['26/02/18'] True
# 00d0976572552.csv [] False
# 00d0976607312.csv ['20-02-18'] True
# 00d0977582300.csv ['09/02/2018'] True
# 00d0978814485.csv [] False
# 00d0979473699.csv ['28/05/18', '28/05/18', '28/05/18'] True
# 00d0981184214.csv ['30-04-2018'] True
# 00d0981274700.csv ['12/01/18'] True
# 00d0982931302.csv ['18/09/2017'] True
# 00d0986033233.csv ['11/01/2018'] True
# 00d0989196649.csv ['02/01/2018'] True
# 00d0989858817.csv ['21-11-16'] True
# 00d0992127574.csv ['10/04/2017'] True
# 00d0992954979.csv [] False
# 00d0992959314.csv ['21/03/2018', '00-13-1300'] True
# 00d0997573916.csv [] False
# 00d0999793595.csv [] False
# 00d0999799045.csv ['26/11/2017'] True

# %%
OCR = pd.read_csv('Bill.com/ocr/00d0320587587.csv', names=["x1","y1","x2","y2","x3","y3","x4","y4","TEXT"])
OCR_STRING = OCR.to_string()
print(OCR_STRING)
# Out:
#      x1   y1   x2   y2   x3   y3   x4   y4                                    TEXT
# 0   127   55  347   55  347   89  127   89                            TAN CHAY YEE
# 1    53   88  415   88  415  127   53  127  S.H.H. MOTOR (SUNGAI RENGIT) SDN. BHD.
# 2   157  126  266  126  266  147  157  147                              (801580-T)
# 3    77  150  392  150  392  170   77  170                                 NO. 343
# 4   124  167  334  167  334  191  124  191                         81620 PENGERANG
# 5    95  191  374  191  374  215   95  215         TEL: 07-8263254 FAX: 07-8266888
# 6   201  234  266  234  266  259  201  259                                 INVOICE
# 7    17  300  103  300  103  323   17  323                              ITEM/DESC.
# 8   253  300  440  300  440  323  253  323                   QTY U.PRICE RM(TOTAL)
# 9    14  343   56  343   56  364   14  364                                    4132
# 10  272  343  290  343  290  369  272  369                                       1
# 11  307  343  353  343  353  367  307  367                                   20.00
# 12  392  344  443  344  443  367  392  367                                   20.00
# 13   19  364  186  364  186  389   19  389                      CROCS 300X17 TUBES
# 14  264  408  360  408  360  428  264  428                             SUB TOTAL :
# 15  396  410  441  410  441  427  396  427                                   20.00
# 16  175  432  360  432  360  449  175  449                   ROUNDING ADJUSTMENT :
# 17  405  433  441  433  441  451  405  451                                    0.00
# 18  241  450  361  450  361  473  241  473                           GRAND TOTAL :
# 19  397  454  439  454  439  472  397  472                                   20.00
# 20  306  475  361  475  361  497  306  497                                  CASH :
# 21  396  473  442  473  442  494  396  494                                   20.00
# 22  289  497  361  497  361  516  289  516                                CHANGE :
# 23  405  497  443  497  443  516  405  516                                    0.00
# 24   15  538  351  538  351  561   15  561                  23-01-2019 13:14:15 PM
# 25   18  560  345  560  345  581   18  581                             TOKEN NO: 0
# 26   14  582  167  582  167  602   14  602                       INVOICE NO: 22497
# 27   15  622  186  622  186  645   15  645                     THANKS YOUR SUPPORT

# %%
trial_OCR = pd.read_csv('Bill.com/ocr/00d0320587587.csv', names=["x1","y1","x2","y2","x3","y3","x4","y4","TEXT"])
TRIAL_OCR_STRING = trial_OCR.to_string()

numeric_re = '\d{2}[,\s/-]\d{2}[,\s/-]\d+'
alphanumeric_re_1 = '(Jan|JAN|Feb|FEB|Mar|MAR|Apr|APR|May|MAY|Jun|JUN|Jul|JUL|Aug|AUG|Sep|SEP|Oct|OCT|Nov|NOV|Dec|DEC)[a-zA-Z.,-]*[,\s/-]?(\d{1,2})?[,\s/-]?\d+'
alphanumeric_re_2 = '(\d{1,2})?[,\s/-]?(Jan|JAN|Feb|FEB|Mar|MAR|Apr|APR|May|MAY|Jun|JUN|Jul|JUL|Aug|AUG|Sep|SEP|Oct|OCT|Nov|NOV|Dec|DEC)[a-zA-Z.,-]*[,\s/-]?\d+'
reg = numeric_re + '|' + alphanumeric_re_1 + '|' + alphanumeric_re_2


dates = re.search(reg, TRIAL_OCR_STRING)
# print(dates.group())
print(dates)
# Out:
# <re.Match object; span=(2135, 2145), match='23-01-2019'>

# %%
dir = 'Bill.com/ocr/'
count = 0
for name in os.listdir(dir):
    if name.endswith(".csv"):
        # print(name)
        OCR_CSV = pd.read_csv(dir + '/' + name, names=["x1","y1","x2","y2","x3","y3","x4","y4","TEXT"], engine='python', on_bad_lines='skip')
        # print(OCR_CSV)
        
        OCR_CSV_STRING = OCR_CSV.to_string()
        dates = re.search(reg, OCR_CSV_STRING)
        
        print(name, dates)
# Out:
# 00d0100894168.csv <re.Match object; span=(5448, 5458), match='11/05/2018'>
# 00d0102367243.csv <re.Match object; span=(646, 656), match='18-06-2018'>
# 00d0103738916.csv <re.Match object; span=(1519, 1529), match='12-02-2018'>
# 00d0106074517.csv <re.Match object; span=(2631, 2639), match='30-04-18'>
# 00d0106280922.csv <re.Match object; span=(1420, 1430), match='15/01/2018'>
# 00d0108922007.csv <re.Match object; span=(1095, 1105), match='25/12/2018'>
# 00d0114026522.csv <re.Match object; span=(799, 809), match='13/01/2018'>
# 00d0114666542.csv <re.Match object; span=(646, 656), match='01-06-2018'>
# 00d0115214912.csv <re.Match object; span=(869, 879), match='10/05/2017'>
# 00d0116292534.csv <re.Match object; span=(4359, 4367), match='07/07/17'>
# 00d0116788763.csv <re.Match object; span=(2255, 2263), match='11-04-18'>
# 00d0118393124.csv <re.Match object; span=(330, 339), match='JAN 27/02'>
# 00d0121860229.csv <re.Match object; span=(2800, 2807), match='MARY\n32'>
# 00d0121880972.csv <re.Match object; span=(1298, 1308), match='13/03/2018'>
# 00d0123031653.csv <re.Match object; span=(790, 800), match='10/02/2017'>
# 00d0124895452.csv <re.Match object; span=(738, 748), match='20/03/2018'>
# 00d0128862298.csv <re.Match object; span=(1104, 1112), match='05-05-18'>
# 00d0130065999.csv <re.Match object; span=(2471, 2479), match='18-04-06'>
# 00d0139330423.csv <re.Match object; span=(870, 880), match='28-05-2018'>
# 00d0139642641.csv <re.Match object; span=(240, 251), match='30 MAY 2018'>
# 00d0142736377.csv <re.Match object; span=(870, 880), match='13-06-2018'>
# 00d0145054354.csv <re.Match object; span=(5028, 5038), match='11/12/2017'>
# 00d0145695018.csv <re.Match object; span=(1131, 1141), match='03/08/2017'>
# 00d0147095939.csv <re.Match object; span=(669, 679), match='13/10/2017'>
# 00d0147748424.csv <re.Match object; span=(234, 245), match='11 JUN 2018'>
# 00d0150882989.csv <re.Match object; span=(1104, 1112), match='07-02-18'>
# 00d0152915085.csv <re.Match object; span=(964, 974), match='04-06-2018'>
# 00d0159517738.csv <re.Match object; span=(1104, 1112), match='14-08-17'>
# 00d0159988592.csv <re.Match object; span=(237, 248), match='11 APR 2018'>
# 00d0164203891.csv <re.Match object; span=(7327, 7334), match='MARY\n77'>
# 00d0164592408.csv <re.Match object; span=(646, 656), match='05-03-2018'>
# 00d0165073570.csv <re.Match object; span=(849, 857), match='27/07/17'>
# 00d0166687964.csv <re.Match object; span=(1204, 1214), match='31/01/2018'>
# 00d0167381962.csv <re.Match object; span=(3390, 3400), match='22/03/2018'>
# 00d0171220341.csv <re.Match object; span=(799, 809), match='11/01/2018'>
# 00d0174068255.csv <re.Match object; span=(1131, 1141), match='10/10/2017'>
# 00d0174270341.csv <re.Match object; span=(1184, 1194), match='21/05/2018'>
# 00d0177909385.csv <re.Match object; span=(4699, 4706), match='MARY\n47'>
# 00d0178057064.csv <re.Match object; span=(613, 621), match='18/06/20'>
# 00d0178282813.csv <re.Match object; span=(353, 363), match='00 88 1231'>
# 00d0178827407.csv <re.Match object; span=(964, 974), match='31-03-2018'>
# 00d0179226173.csv <re.Match object; span=(646, 656), match='11-06-2018'>
# 00d0180967427.csv <re.Match object; span=(1324, 1334), match='22-06-2017'>
# 00d0182384739.csv <re.Match object; span=(1248, 1258), match='24/08/2017'>
# 00d0183401385.csv <re.Match object; span=(861, 871), match='10/03/2018'>
# 00d0184132278.csv <re.Match object; span=(1411, 1421), match='02/05/2018'>
# 00d0185599105.csv <re.Match object; span=(1925, 1933), match='25-01-16'>
# 00d0186887844.csv <re.Match object; span=(2271, 2279), match='23-03-18'>
# 00d0188523936.csv <re.Match object; span=(871, 879), match='10-05-17'>
# 00d0189067460.csv <re.Match object; span=(5331, 5339), match='11/04/18'>
# 00d0191077139.csv <re.Match object; span=(3177, 3184), match='MARY\n42'>
# 00d0192025858.csv <re.Match object; span=(1131, 1141), match='05/08/2017'>
# 00d0194796076.csv <re.Match object; span=(929, 939), match='21/08/2017'>
# 00d0196808024.csv <re.Match object; span=(4367, 4377), match='05/07/2017'>
# 00d0196984382.csv <re.Match object; span=(1741, 1751), match='06/12/2016'>
# 00d0198786728.csv <re.Match object; span=(164, 173), match=' MARKET\n1'>
# 00d0201738305.csv <re.Match object; span=(1309, 1319), match='10/03/2018'>
# 00d0201817639.csv <re.Match object; span=(609, 617), match='01/03/18'>
# 00d0201833623.csv <re.Match object; span=(860, 868), match='23/12/17'>
# 00d0202365816.csv <re.Match object; span=(1730, 1737), match='32-41/2'>
# 00d0204688228.csv <re.Match object; span=(869, 879), match='13/07/2017'>
# 00d0206117546.csv <re.Match object; span=(234, 245), match='10 MAY 2018'>
# 00d0206227401.csv <re.Match object; span=(4483, 4493), match='08/07/2017'>
# 00d0206414354.csv <re.Match object; span=(709, 719), match='02/12/2017'>
# 00d0207352920.csv <re.Match object; span=(5655, 5665), match='29/11/2017'>
# 00d0207985673.csv <re.Match object; span=(5179, 5189), match='28/03/2017'>
# 00d0212306806.csv <re.Match object; span=(870, 880), match='23-06-2018'>
# 00d0212522180.csv <re.Match object; span=(1122, 1132), match='12/02/2018'>
# 00d0215894408.csv <re.Match object; span=(1411, 1421), match='11/05/2018'>
# 00d0218523505.csv <re.Match object; span=(1248, 1258), match='25/07/2017'>
# 00d0220981260.csv <re.Match object; span=(869, 879), match='29/12/2017'>
# 00d0223498663.csv <re.Match object; span=(1124, 1134), match='25/12/2016'>
# 00d0223598140.csv <re.Match object; span=(1009, 1019), match='16/06/2018'>
# 00d0225816395.csv <re.Match object; span=(1131, 1141), match='17/08/2017'>
# 00d0230547657.csv <re.Match object; span=(869, 879), match='15/11/2017'>
# 00d0233173701.csv <re.Match object; span=(595, 605), match='18/04/2018'>
# 00d0234070159.csv <re.Match object; span=(889, 899), match='01/02/2018'>
# 00d0235890341.csv <re.Match object; span=(1469, 1479), match='22/01/2017'>
# 00d0237756126.csv <re.Match object; span=(4483, 4493), match='15/07/2017'>
# 00d0238897436.csv <re.Match object; span=(1253, 1263), match='12/01/2018'>
# 00d0240488407.csv <re.Match object; span=(2361, 2368), match='21-31/2'>
# 00d0241023069.csv <re.Match object; span=(8921, 8931), match='01/04/2018'>
# 00d0242366463.csv <re.Match object; span=(843, 851), match='16-07-31'>
# 00d0242626168.csv <re.Match object; span=(1177, 1187), match='17/01/2018'>
# 00d0243046961.csv <re.Match object; span=(615, 623), match='29/03/18'>
# 00d0243521534.csv <re.Match object; span=(1105, 1115), match='19/03/2018'>
# 00d0245826221.csv <re.Match object; span=(1104, 1112), match='04-06-18'>
# 00d0250566763.csv <re.Match object; span=(982, 993), match='25/FEB/2017'>
# 00d0255697730.csv <re.Match object; span=(984, 994), match='06/05/2018'>
# 00d0258506946.csv <re.Match object; span=(599, 609), match='08/04/2018'>
# 00d0259127407.csv <re.Match object; span=(2916, 2924), match='21/02/18'>
# 00d0259552507.csv <re.Match object; span=(955, 966), match='05-JAN-2017'>
# 00d0261309649.csv <re.Match object; span=(926, 934), match='27/06/18'>
# 00d0263805728.csv <re.Match object; span=(1156, 1162), match=' OCT 3'>
# 00d0266548523.csv <re.Match object; span=(849, 857), match='09/08/17'>
# 00d0267909555.csv <re.Match object; span=(4712, 4722), match='12/03/2018'>
# 00d0269258457.csv <re.Match object; span=(859, 869), match='15/09/2017'>
# 00d0270398034.csv <re.Match object; span=(1014, 1024), match='29/10/2017'>
# 00d0270792056.csv <re.Match object; span=(1133, 1143), match='20/05/2018'>
# 00d0271405634.csv <re.Match object; span=(991, 999), match='17/05/17'>
# 00d0271842165.csv <re.Match object; span=(1042, 1052), match='12/02/2018'>
# 00d0272031259.csv <re.Match object; span=(234, 245), match='15 MAY 2018'>
# 00d0272306272.csv <re.Match object; span=(4367, 4377), match='21/03/2017'>
# 00d0277307035.csv <re.Match object; span=(959, 969), match='14-06-2018'>
# 00d0280864237.csv <re.Match object; span=(1447, 1457), match='31/03/2018'>
# 00d0281320276.csv <re.Match object; span=(1432, 1442), match='20/11/2017'>
# 00d0282138675.csv <re.Match object; span=(1131, 1141), match='24/07/2017'>
# 00d0282395578.csv <re.Match object; span=(4483, 4493), match='19/07/2017'>
# 00d0286887687.csv <re.Match object; span=(869, 879), match='04/12/2017'>
# 00d0288011947.csv <re.Match object; span=(1060, 1070), match='25/05/2018'>
# 00d0289417092.csv <re.Match object; span=(803, 813), match='22/12/2017'>
# 00d0290184065.csv <re.Match object; span=(5028, 5038), match='04/12/2017'>
# 00d0292723088.csv <re.Match object; span=(646, 654), match='02/03/18'>
# 00d0293069545.csv <re.Match object; span=(646, 656), match='26-06-2018'>
# 00d0294263018.csv <re.Match object; span=(609, 617), match='01/03/18'>
# 00d0307106203.csv <re.Match object; span=(1164, 1172), match='07-02-17'>
# 00d0307768744.csv <re.Match object; span=(1739, 1747), match='26-04-18'>
# 00d0308106888.csv <re.Match object; span=(557, 571), match='MART-ACC.COM\n5'>
# 00d0308915412.csv <re.Match object; span=(916, 926), match='27/05/2018'>
# 00d0313212291.csv <re.Match object; span=(948, 958), match='24/07/2016'>
# 00d0314913072.csv <re.Match object; span=(1343, 1351), match='09/02/17'>
# 00d0316894686.csv <re.Match object; span=(1187, 1197), match='09/02/2018'>
# 00d0318453525.csv <re.Match object; span=(839, 849), match='08/04/2018'>
# 00d0319760858.csv <re.Match object; span=(1277, 1287), match='09/03/2018'>
# 00d0320587587.csv None
# 00d0320901819.csv <re.Match object; span=(911, 919), match='19/05/18'>
# 00d0326687304.csv <re.Match object; span=(7060, 7070), match='28/12/2017'>
# 00d0328708236.csv <re.Match object; span=(621, 631), match='27/09/2017'>
# 00d0330285744.csv <re.Match object; span=(678, 685), match='12/48\n8'>
# 00d0330533884.csv <re.Match object; span=(1131, 1141), match='19/08/2017'>
# 00d0333208815.csv <re.Match object; span=(237, 248), match='16 APR 2018'>
# 00d0334664099.csv <re.Match object; span=(497, 507), match='18-03-2018'>
# 00d0338048914.csv <re.Match object; span=(1447, 1457), match='06/03/2018'>
# 00d0338271694.csv <re.Match object; span=(870, 880), match='28-04-2018'>
# 00d0338418904.csv <re.Match object; span=(4401, 4409), match='18-11-18'>
# 00d0338548353.csv <re.Match object; span=(1148, 1156), match='28/04/18'>
# 00d0339705365.csv <re.Match object; span=(1213, 1223), match='30/05/2017'>
# 00d0340785534.csv <re.Match object; span=(2959, 2966), match='MARY\n38'>
# 00d0343958098.csv <re.Match object; span=(712, 720), match='18/06/09'>
# 00d0346543074.csv <re.Match object; span=(814, 824), match='09/01/2019'>
# 00d0347606159.csv <re.Match object; span=(3816, 3826), match='29-10-2017'>
# 00d0353042107.csv <re.Match object; span=(880, 890), match='30/09/2017'>
# 00d0353443719.csv <re.Match object; span=(3623, 3633), match='09/03/2018'>
# 00d0354051709.csv <re.Match object; span=(1301, 1311), match='02/02/2018'>
# 00d0354593861.csv <re.Match object; span=(847, 857), match='11/06/2018'>
# 00d0355426817.csv <re.Match object; span=(982, 992), match='13/04/2018'>
# 00d0358154075.csv <re.Match object; span=(4367, 4377), match='07/11/2017'>
# 00d0362311019.csv <re.Match object; span=(1055, 1063), match='04-06-16'>
# 00d0363399593.csv <re.Match object; span=(1776, 1782), match='MAR\n19'>
# 00d0363991072.csv <re.Match object; span=(860, 868), match='25/04/18'>
# 00d0365513088.csv <re.Match object; span=(213, 224), match='30 MAR 2018'>
# 00d0366117594.csv <re.Match object; span=(2754, 2761), match='MARY\n30'>
# 00d0366175414.csv <re.Match object; span=(234, 245), match='18 APR 2018'>
# 00d0372099873.csv <re.Match object; span=(609, 617), match='24/01/18'>
# 00d0374072400.csv <re.Match object; span=(870, 880), match='22-05-2018'>
# 00d0375035482.csv <re.Match object; span=(399, 409), match='09/04/2018'>
# 00d0377572170.csv <re.Match object; span=(882, 893), match='14/JUN/2017'>
# 00d0377951457.csv <re.Match object; span=(541, 551), match='25-03-2018'>
# 00d0379996414.csv <re.Match object; span=(210, 221), match='19 MAR 2018'>
# 00d0382500008.csv <re.Match object; span=(1111, 1122), match='04 JAN 2017'>
# 00d0383639350.csv <re.Match object; span=(1429, 1439), match='10/06/2018'>
# 00d0384888865.csv <re.Match object; span=(789, 797), match='23/06/18'>
# 00d0385248621.csv <re.Match object; span=(540, 547), match='64/66\n6'>
# 00d0388190762.csv <re.Match object; span=(475, 485), match='21/10/2017'>
# 00d0388919382.csv <re.Match object; span=(4483, 4493), match='20/10/2017'>
# 00d0389135415.csv <re.Match object; span=(1572, 1579), match='MARY\n18'>
# 00d0390492165.csv <re.Match object; span=(772, 782), match='31/03/2017'>
# 00d0393260166.csv <re.Match object; span=(1131, 1141), match='14/10/2017'>
# 00d0394931168.csv <re.Match object; span=(3465, 3475), match='21/03/2018'>
# 00d0395061839.csv <re.Match object; span=(914, 924), match='02/02/2017'>
# 00d0396057665.csv <re.Match object; span=(809, 819), match='23/03/2018'>
# 00d0396141876.csv <re.Match object; span=(399, 409), match='10/03/2018'>
# 00d0397644256.csv <re.Match object; span=(1045, 1055), match='22/02/2018'>
# 00d0400479663.csv <re.Match object; span=(799, 809), match='04/01/2018'>
# 00d0401609886.csv <re.Match object; span=(1131, 1141), match='22/10/2017'>
# 00d0402998841.csv <re.Match object; span=(646, 656), match='06-05-2018'>
# 00d0403711886.csv <re.Match object; span=(799, 809), match='10/01/2018'>
# 00d0407044350.csv <re.Match object; span=(1131, 1141), match='30/09/2017'>
# 00d0408017404.csv <re.Match object; span=(869, 879), match='15/06/2017'>
# 00d0408489357.csv <re.Match object; span=(243, 254), match='24 MAY 2018'>
# 00d0411132243.csv <re.Match object; span=(1131, 1141), match='26/10/2017'>
# 00d0411843053.csv <re.Match object; span=(646, 656), match='09-04-2018'>
# 00d0414196980.csv <re.Match object; span=(646, 656), match='14-03-2018'>
# 00d0415751725.csv <re.Match object; span=(768, 776), match='25/06/18'>
# 00d0416161702.csv <re.Match object; span=(676, 684), match='17-12-28'>
# 00d0417300467.csv <re.Match object; span=(969, 979), match='02/03/2018'>
# 00d0419719085.csv <re.Match object; span=(898, 909), match='25 MAY 2017'>
# 00d0422368687.csv <re.Match object; span=(511, 521), match='12/05/2018'>
# 00d0423671916.csv <re.Match object; span=(751, 761), match='19/09/2017'>
# 00d0426803895.csv <re.Match object; span=(4658, 4668), match='19/03/2018'>
# 00d0432757654.csv <re.Match object; span=(399, 409), match='13/04/2018'>
# 00d0435331752.csv <re.Match object; span=(1411, 1421), match='03/05/2018'>
# 00d0437873955.csv <re.Match object; span=(1258, 1268), match='10-03-2018'>
# 00d0439076290.csv <re.Match object; span=(1179, 1187), match='32-51-71'>
# 00d0443302756.csv <re.Match object; span=(646, 656), match='05-05-2018'>
# 00d0443910003.csv <re.Match object; span=(617, 625), match='05/03/18'>
# 00d0447521528.csv <re.Match object; span=(3839, 3847), match='06-04-18'>
# 00d0448828100.csv <re.Match object; span=(1109, 1119), match='15/03/2018'>
# 00d0449236994.csv <re.Match object; span=(957, 967), match='10/08/2017'>
# 00d0449498451.csv <re.Match object; span=(1021, 1031), match='18/03/2018'>
# 00d0450998902.csv <re.Match object; span=(495, 505), match='00-88-5200'>
# 00d0452553939.csv <re.Match object; span=(234, 245), match='16 MAY 2018'>
# 00d0453226524.csv <re.Match object; span=(932, 943), match='14/MAY/2017'>
# 00d0453489586.csv <re.Match object; span=(3874, 3884), match='22/04/2018'>
# 00d0453904564.csv <re.Match object; span=(1131, 1141), match='19/10/2017'>
# 00d0457456115.csv <re.Match object; span=(1050, 1060), match='14-02-2018'>
# 00d0458708415.csv <re.Match object; span=(1131, 1141), match='25/08/2017'>
# 00d0459172796.csv <re.Match object; span=(1131, 1141), match='05/09/2017'>
# 00d0463604996.csv <re.Match object; span=(216, 227), match='21 MAR 2018'>
# 00d0464021737.csv <re.Match object; span=(639, 647), match='06/04/17'>
# 00d0464742744.csv <re.Match object; span=(5063, 5073), match='20/09/2017'>
# 00d0471112949.csv <re.Match object; span=(851, 859), match='02/06/18'>
# 00d0471481845.csv <re.Match object; span=(707, 714), match='41-51/2'>
# 00d0471591245.csv <re.Match object; span=(995, 1003), match='15/04/18'>
# 00d0472127340.csv <re.Match object; span=(1711, 1718), match='MARY\n21'>
# 00d0472780579.csv <re.Match object; span=(646, 656), match='04-04-2018'>
# 00d0472913563.csv <re.Match object; span=(818, 828), match='07/05/2018'>
# 00d0474678678.csv <re.Match object; span=(5095, 5103), match='19/05/18'>
# 00d0477553790.csv <re.Match object; span=(4662, 4672), match='15/07/2017'>
# 00d0483826961.csv <re.Match object; span=(646, 656), match='30/03/2018'>
# 00d0484705589.csv <re.Match object; span=(979, 989), match='03/07/2018'>
# 00d0484942812.csv <re.Match object; span=(968, 978), match='04/12/2017'>
# 00d0485748096.csv <re.Match object; span=(1055, 1063), match='03-02-16'>
# 00d0485758378.csv <re.Match object; span=(799, 809), match='02/01/2018'>
# 00d0485821436.csv <re.Match object; span=(2558, 2566), match='01 05/01'>
# 00d0487139957.csv <re.Match object; span=(948, 958), match='11-06-2018'>
# 00d0489061247.csv <re.Match object; span=(1085, 1095), match='14/05/2018'>
# 00d0490682838.csv <re.Match object; span=(4483, 4493), match='06/07/2017'>
# 00d0495694280.csv <re.Match object; span=(4483, 4493), match='24/07/2017'>
# 00d0497274391.csv <re.Match object; span=(4483, 4493), match='06/09/2017'>
# 00d0500564944.csv <re.Match object; span=(2091, 2099), match='27-04-18'>
# 00d0500910371.csv <re.Match object; span=(1051, 1059), match='18-03-18'>
# 00d0502129574.csv <re.Match object; span=(5831, 5841), match='22/04/2018'>
# 00d0504003816.csv <re.Match object; span=(646, 656), match='12-06-2018'>
# 00d0504725741.csv <re.Match object; span=(707, 719), match='04-18/084227'>
# 00d0507143553.csv <re.Match object; span=(820, 830), match='01/06/2018'>
# 00d0508747957.csv <re.Match object; span=(1220, 1230), match='03/04/2018'>
# 00d0510871247.csv <re.Match object; span=(1131, 1141), match='03/09/2017'>
# 00d0511840834.csv <re.Match object; span=(1591, 1598), match='MARY\n20'>
# 00d0513207673.csv <re.Match object; span=(847, 857), match='20/03/2018'>
# 00d0523654121.csv <re.Match object; span=(983, 991), match='03-02-18'>
# 00d0524794165.csv <re.Match object; span=(851, 859), match='10-05-17'>
# 00d0527382713.csv <re.Match object; span=(809, 819), match='02/01/2018'>
# 00d0529128132.csv <re.Match object; span=(237, 248), match='22 MAY 2018'>
# 00d0530467663.csv <re.Match object; span=(4391, 4399), match='24/05/18'>
# 00d0530724847.csv <re.Match object; span=(505, 515), match='19-03-2018'>
# 00d0531848355.csv <re.Match object; span=(240, 251), match='18 JUN 2018'>
# 00d0532350198.csv <re.Match object; span=(612, 622), match='09/03/2018'>
# 00d0533588228.csv <re.Match object; span=(643, 653), match='14/03/2018'>
# 00d0537233731.csv <re.Match object; span=(1541, 1551), match='13/06/2018'>
# 00d0539072705.csv <re.Match object; span=(695, 705), match='17/06/2018'>
# 00d0541369548.csv <re.Match object; span=(765, 775), match='13-02-2016'>
# 00d0542157895.csv <re.Match object; span=(617, 625), match='27/02/18'>
# 00d0542888628.csv <re.Match object; span=(1055, 1063), match='24-01-16'>
# 00d0543055869.csv <re.Match object; span=(590, 598), match='18-01-05'>
# 00d0543406251.csv <re.Match object; span=(4367, 4377), match='12/08/2017'>
# 00d0546591203.csv <re.Match object; span=(957, 967), match='28/12/2017'>
# 00d0547495073.csv <re.Match object; span=(1390, 1400), match='18/06/2018'>
# 00d0547632877.csv <re.Match object; span=(1865, 1872), match='MARY\n21'>
# 00d0550391706.csv <re.Match object; span=(1104, 1112), match='13-05-18'>
# 00d0551541808.csv <re.Match object; span=(3688, 3696), match='12-01-19'>
# 00d0552375573.csv <re.Match object; span=(869, 879), match='04/09/2017'>
# 00d0552638268.csv <re.Match object; span=(540, 547), match='40/20\n6'>
# 00d0553233477.csv <re.Match object; span=(1340, 1350), match='16/02/2018'>
# 00d0555910882.csv <re.Match object; span=(1269, 1279), match='28/02/2018'>
# 00d0556108338.csv <re.Match object; span=(237, 248), match='16 JUN 2018'>
# 00d0558270937.csv <re.Match object; span=(234, 245), match='09 APR 2018'>
# 00d0564198512.csv <re.Match object; span=(1296, 1306), match='03/06/2017'>
# 00d0564199588.csv <re.Match object; span=(869, 879), match='25/12/2017'>
# 00d0568013096.csv <re.Match object; span=(1137, 1147), match='02/03/2018'>
# 00d0570374781.csv <re.Match object; span=(3771, 3781), match='12/04/2018'>
# 00d0572439292.csv <re.Match object; span=(2635, 2643), match='26-03-18'>
# 00d0574862056.csv <re.Match object; span=(1351, 1359), match='26/03/18'>
# 00d0576905492.csv <re.Match object; span=(962, 971), match='15 JUN 18'>
# 00d0577470816.csv <re.Match object; span=(237, 248), match='02 APR 2018'>
# 00d0581923422.csv <re.Match object; span=(579, 589), match='14/04/2018'>
# 00d0582681704.csv <re.Match object; span=(832, 842), match='05/01/2018'>
# 00d0582732557.csv <re.Match object; span=(593, 603), match='25/09/2017'>
# 00d0583684114.csv <re.Match object; span=(1048, 1058), match='24/06/2018'>
# 00d0585896483.csv <re.Match object; span=(1248, 1258), match='27/07/2017'>
# 00d0588374381.csv None
# 00d0594663786.csv <re.Match object; span=(3875, 3883), match='01/05/16'>
# 00d0595804986.csv <re.Match object; span=(1055, 1063), match='30-06-16'>
# 00d0599423844.csv <re.Match object; span=(1145, 1155), match='27/03/2018'>
# 00d0599930970.csv <re.Match object; span=(990, 1000), match='13-09-2017'>
# 00d0600715913.csv <re.Match object; span=(369, 379), match='00 88 1231'>
# 00d0601744334.csv <re.Match object; span=(1131, 1141), match='25/09/2017'>
# 00d0602427476.csv <re.Match object; span=(213, 224), match='18 MAR 2018'>
# 00d0603631647.csv <re.Match object; span=(1617, 1627), match='30/04/2017'>
# 00d0606455264.csv <re.Match object; span=(1447, 1457), match='28/02/2018'>
# 00d0606540603.csv <re.Match object; span=(869, 879), match='12/01/2018'>
# 00d0607552804.csv <re.Match object; span=(781, 791), match='10/10/2017'>
# 00d0608126101.csv <re.Match object; span=(5242, 5250), match='17/04/18'>
# 00d0608566104.csv <re.Match object; span=(4483, 4493), match='18/04/2017'>
# 00d0610473999.csv <re.Match object; span=(1019, 1029), match='17/01/2018'>
# 00d0614628355.csv <re.Match object; span=(572, 582), match='21-03-2018'>
# 00d0616798510.csv <re.Match object; span=(1104, 1112), match='05-05-17'>
# 00d0617357249.csv <re.Match object; span=(4286, 4296), match='27/05/2018'>
# 00d0619690945.csv <re.Match object; span=(982, 993), match='02/JAN/2017'>
# 00d0622420051.csv <re.Match object; span=(4440, 4450), match='12/06/2018'>
# 00d0624439175.csv <re.Match object; span=(3433, 3441), match='17-04-16'>
# 00d0626463001.csv <re.Match object; span=(213, 224), match='03 MAR 2018'>
# 00d0627357411.csv <re.Match object; span=(1152, 1160), match='23-33-53'>
# 00d0627737900.csv <re.Match object; span=(879, 889), match='29/10/2017'>
# 00d0628164309.csv <re.Match object; span=(237, 248), match='10 APR 2018'>
# 00d0630325043.csv <re.Match object; span=(1045, 1055), match='02/01/2018'>
# 00d0632172733.csv <re.Match object; span=(835, 845), match='09/06/2018'>
# 00d0632354255.csv <re.Match object; span=(664, 672), match='03-04-06'>
# 00d0634485458.csv <re.Match object; span=(469, 476), match='10/10\n4'>
# 00d0635477367.csv <re.Match object; span=(1134, 1142), match='12/48\n14'>
# 00d0638988191.csv <re.Match object; span=(1131, 1141), match='18/10/2017'>
# 00d0639354292.csv <re.Match object; span=(213, 224), match='10 MAR 2018'>
# 00d0641642649.csv <re.Match object; span=(879, 889), match='20/03/2017'>
# 00d0645069761.csv <re.Match object; span=(833, 843), match='25/04/2017'>
# 00d0647759775.csv <re.Match object; span=(3518, 3528), match='30-09-2017'>
# 00d0648982621.csv <re.Match object; span=(3821, 3831), match='19/02/2018'>
# 00d0649375713.csv <re.Match object; span=(1057, 1067), match='07/04/2018'>
# 00d0652046562.csv <re.Match object; span=(1743, 1750), match='MARY\n22'>
# 00d0654270874.csv <re.Match object; span=(322, 329), match='21/35\n3'>
# 00d0654632791.csv <re.Match object; span=(1411, 1421), match='17/04/2018'>
# 00d0658523473.csv <re.Match object; span=(2911, 2919), match='20/06/18'>
# 00d0660852423.csv <re.Match object; span=(1108, 1117), match=' JUN/2018'>
# 00d0661661607.csv <re.Match object; span=(1131, 1141), match='28/09/2017'>
# 00d0664097059.csv <re.Match object; span=(2838, 2848), match='11/12/2017'>
# 00d0665595833.csv <re.Match object; span=(1104, 1112), match='05-12-16'>
# 00d0667274990.csv <re.Match object; span=(870, 880), match='30-05-2018'>
# 00d0668346631.csv <re.Match object; span=(1104, 1112), match='17-02-18'>
# 00d0668503128.csv <re.Match object; span=(1368, 1375), match=' MAR 18'>
# 00d0674212079.csv <re.Match object; span=(4599, 4609), match='18/07/2017'>
# 00d0674219107.csv <re.Match object; span=(1616, 1626), match='08/02/2017'>
# 00d0675832982.csv <re.Match object; span=(883, 893), match='20/03/2018'>
# 00d0676485252.csv <re.Match object; span=(213, 224), match='22 MAR 2018'>
# 00d0676711962.csv <re.Match object; span=(667, 675), match='21-41-61'>
# 00d0677299556.csv <re.Match object; span=(1055, 1063), match='11-05-16'>
# 00d0678037496.csv <re.Match object; span=(819, 829), match='20/10/2016'>
# 00d0678943517.csv <re.Match object; span=(860, 870), match='29/03/2018'>
# 00d0680000515.csv <re.Match object; span=(1248, 1258), match='21/07/2017'>
# 00d0680178711.csv <re.Match object; span=(1139, 1149), match='27/04/2018'>
# 00d0682202857.csv <re.Match object; span=(1159, 1169), match='12/02/2018'>
# 00d0682248746.csv <re.Match object; span=(1104, 1112), match='28-11-18'>
# 00d0682329345.csv <re.Match object; span=(1104, 1112), match='22-11-17'>
# 00d0685059326.csv <re.Match object; span=(1111, 1122), match='05 JAN 2017'>
# 00d0685723809.csv <re.Match object; span=(860, 870), match='19-04-2018'>
# 00d0686078737.csv <re.Match object; span=(1092, 1102), match='24-03-2018'>
# 00d0689877704.csv <re.Match object; span=(1104, 1112), match='04-06-18'>
# 00d0692025607.csv <re.Match object; span=(646, 656), match='12-03-2018'>
# 00d0692152542.csv <re.Match object; span=(4483, 4493), match='24/05/2017'>
# 00d0694169739.csv <re.Match object; span=(839, 849), match='11/05/2018'>
# 00d0694627982.csv <re.Match object; span=(1189, 1199), match='22/03/2018'>
# 00d0695919511.csv <re.Match object; span=(2895, 2903), match='03/06/18'>
# 00d0696021247.csv <re.Match object; span=(1150, 1160), match='23-04-2017'>
# 00d0696518680.csv <re.Match object; span=(1187, 1197), match='03/02/2018'>
# 00d0697219524.csv <re.Match object; span=(866, 877), match='24-MAR-2018'>
# 00d0698784211.csv <re.Match object; span=(4483, 4493), match='27/10/2017'>
# 00d0702366697.csv <re.Match object; span=(573, 583), match='27/03/2018'>
# 00d0702501060.csv <re.Match object; span=(750, 758), match='30/05/18'>
# 00d0702637244.csv <re.Match object; span=(3821, 3831), match='28/04/2018'>
# 00d0705950948.csv <re.Match object; span=(1131, 1141), match='08/10/2017'>
# 00d0708429922.csv <re.Match object; span=(1131, 1141), match='20/10/2017'>
# 00d0710387537.csv <re.Match object; span=(1032, 1040), match='11/03/18'>
# 00d0711624382.csv <re.Match object; span=(1068, 1078), match='21-03-2018'>
# 00d0714317145.csv <re.Match object; span=(869, 879), match='12/09/2017'>
# 00d0715617779.csv <re.Match object; span=(542, 552), match='27/06/2018'>
# 00d0716702145.csv <re.Match object; span=(1104, 1112), match='02-05-18'>
# 00d0717257644.csv <re.Match object; span=(955, 966), match='05-JAN-2017'>
# 00d0720874250.csv <re.Match object; span=(234, 245), match='10 JUN 2018'>
# 00d0721665358.csv None
# 00d0722335566.csv <re.Match object; span=(1131, 1141), match='25/10/2017'>
# 00d0723945064.csv <re.Match object; span=(860, 870), match='29/03/2018'>
# 00d0724139826.csv <re.Match object; span=(1269, 1279), match='17/01/2018'>
# 00d0724729985.csv <re.Match object; span=(3687, 3695), match='11/02/16'>
# 00d0726056883.csv <re.Match object; span=(646, 656), match='26-06-2018'>
# 00d0726102139.csv <re.Match object; span=(5295, 5305), match='07/05/2017'>
# 00d0726523245.csv <re.Match object; span=(1834, 1842), match='12/48\n22'>
# 00d0729993616.csv <re.Match object; span=(1411, 1421), match='30/04/2018'>
# 00d0733466225.csv <re.Match object; span=(810, 820), match='08/02/2017'>
# 00d0734092781.csv <re.Match object; span=(1578, 1586), match='23-33-53'>
# 00d0734493835.csv <re.Match object; span=(985, 995), match='28/12/2017'>
# 00d0737345187.csv <re.Match object; span=(1041, 1049), match='02/02/17'>
# 00d0737981299.csv <re.Match object; span=(2179, 2187), match='22-05-16'>
# 00d0738014969.csv <re.Match object; span=(779, 789), match='03/03/2018'>
# 00d0741622526.csv <re.Match object; span=(646, 656), match='06-05-2018'>
# 00d0742987288.csv <re.Match object; span=(4599, 4609), match='22/05/2017'>
# 00d0743614936.csv <re.Match object; span=(1547, 1557), match='14/03/2018'>
# 00d0744539202.csv <re.Match object; span=(781, 789), match='21-05-17'>
# 00d0745331693.csv <re.Match object; span=(1411, 1421), match='20/04/2018'>
# 00d0747284670.csv <re.Match object; span=(3193, 3200), match='MARY\n40'>
# 00d0749169797.csv <re.Match object; span=(1248, 1258), match='28/08/2017'>
# 00d0749657219.csv <re.Match object; span=(523, 533), match='15/12/2016'>
# 00d0749666123.csv <re.Match object; span=(685, 695), match='04/12/2017'>
# 00d0750315464.csv <re.Match object; span=(799, 809), match='03/01/2018'>
# 00d0751097262.csv <re.Match object; span=(870, 880), match='19-05-2018'>
# 00d0752144290.csv <re.Match object; span=(1059, 1069), match='09-04-2018'>
# 00d0752976763.csv <re.Match object; span=(1654, 1662), match='25/50\n19'>
# 00d0757215171.csv <re.Match object; span=(1199, 1209), match='17/04/2018'>
# 00d0757440459.csv <re.Match object; span=(3190, 3200), match='06/03/2018'>
# 00d0757881141.csv <re.Match object; span=(2461, 2469), match='18/03/18'>
# 00d0758726468.csv <re.Match object; span=(1309, 1319), match='03/02/2018'>
# 00d0760304510.csv <re.Match object; span=(2175, 2183), match='06-04-16'>
# 00d0760612254.csv <re.Match object; span=(540, 547), match='64/66\n6'>
# 00d0761346037.csv None
# 00d0763228450.csv <re.Match object; span=(703, 711), match='18/06/04'>
# 00d0763327632.csv <re.Match object; span=(414, 424), match='14/04/2018'>
# 00d0764796072.csv <re.Match object; span=(1190, 1200), match='16/04/2018'>
# 00d0764855917.csv <re.Match object; span=(1552, 1562), match='20/12/2017'>
# 00d0768446621.csv <re.Match object; span=(693, 701), match='06/02/18'>
# 00d0770154989.csv <re.Match object; span=(830, 840), match='22/12/2017'>
# 00d0770792669.csv <re.Match object; span=(1131, 1141), match='08/09/2017'>
# 00d0772671396.csv <re.Match object; span=(839, 847), match='04-05-18'>
# 00d0773577731.csv <re.Match object; span=(4831, 4838), match='MARY\n61'>
# 00d0774260218.csv <re.Match object; span=(880, 889), match='24 MAR 18'>
# 00d0776331594.csv <re.Match object; span=(615, 625), match='26/02/2018'>
# 00d0776440475.csv <re.Match object; span=(4599, 4609), match='10/04/2017'>
# 00d0777749051.csv <re.Match object; span=(2020, 2027), match='MARY\n24'>
# 00d0778866561.csv <re.Match object; span=(5179, 5189), match='18/11/2017'>
# 00d0781074499.csv <re.Match object; span=(256, 262), match='MART\n2'>
# 00d0782503250.csv <re.Match object; span=(1148, 1156), match='28/04/18'>
# 00d0784103375.csv <re.Match object; span=(5179, 5189), match='04/04/2017'>
# 00d0784934925.csv <re.Match object; span=(1235, 1245), match='14/01/2018'>
# 00d0785646736.csv <re.Match object; span=(646, 656), match='14-03-2018'>
# 00d0787822677.csv <re.Match object; span=(579, 589), match='17/05/2018'>
# 00d0788646334.csv <re.Match object; span=(1411, 1421), match='26/05/2018'>
# 00d0793133421.csv <re.Match object; span=(748, 756), match='04/12/17'>
# 00d0795468800.csv <re.Match object; span=(896, 904), match='01 01\n10'>
# 00d0796308197.csv <re.Match object; span=(946, 954), match='18/03/18'>
# 00d0797361085.csv <re.Match object; span=(1122, 1132), match='01/10/2017'>
# 00d0797433528.csv <re.Match object; span=(1274, 1282), match='21-41-71'>
# 00d0803190070.csv <re.Match object; span=(4483, 4493), match='18/04/2017'>
# 00d0805870344.csv <re.Match object; span=(637, 645), match='19/05/16'>
# 00d0806991732.csv <re.Match object; span=(1131, 1141), match='30/10/2017'>
# 00d0809037791.csv <re.Match object; span=(646, 656), match='26-05-2018'>
# 00d0810901932.csv <re.Match object; span=(705, 713), match='19/01/17'>
# 00d0815578182.csv <re.Match object; span=(646, 656), match='30-06-2018'>
# 00d0815885891.csv <re.Match object; span=(737, 747), match='16-04-2018'>
# 00d0817657245.csv <re.Match object; span=(4483, 4493), match='31/10/2017'>
# 00d0817761748.csv <re.Match object; span=(234, 245), match='12 JUN 2018'>
# 00d0818342590.csv <re.Match object; span=(870, 880), match='20-06-2018'>
# 00d0818597221.csv <re.Match object; span=(7484, 7494), match='28/02/2018'>
# 00d0820736669.csv <re.Match object; span=(1131, 1141), match='29/09/2017'>
# 00d0821795963.csv <re.Match object; span=(240, 251), match='05 MAY 2018'>
# 00d0826414442.csv <re.Match object; span=(790, 800), match='10/02/2017'>
# 00d0827574327.csv <re.Match object; span=(1104, 1112), match='01-11-17'>
# 00d0827589883.csv <re.Match object; span=(882, 892), match='29/03/2018'>
# 00d0827595193.csv <re.Match object; span=(1204, 1214), match='03/02/2018'>
# 00d0828214133.csv <re.Match object; span=(961, 971), match='24/01/2018'>
# 00d0828995688.csv <re.Match object; span=(883, 893), match='20/03/2018'>
# 00d0831136284.csv <re.Match object; span=(982, 992), match='02/02/2018'>
# 00d0831212127.csv <re.Match object; span=(1019, 1029), match='23/01/2018'>
# 00d0831446713.csv <re.Match object; span=(3201, 3209), match='26/06/18'>
# 00d0832645976.csv <re.Match object; span=(869, 879), match='28/09/2017'>
# 00d0834036599.csv <re.Match object; span=(573, 583), match='27/03/2018'>
# 00d0835959293.csv <re.Match object; span=(2708, 2718), match='23/03/2018'>
# 00d0837787542.csv <re.Match object; span=(1446, 1456), match='20/12/2017'>
# 00d0837897960.csv <re.Match object; span=(675, 683), match='06/01/18'>
# 00d0840814576.csv <re.Match object; span=(1131, 1141), match='17/10/2017'>
# 00d0841246769.csv <re.Match object; span=(237, 248), match='03 APR 2018'>
# 00d0841330621.csv <re.Match object; span=(817, 829), match='03-18/199913'>
# 00d0842605090.csv <re.Match object; span=(1014, 1024), match='18/09/2017'>
# 00d0843646516.csv <re.Match object; span=(1131, 1141), match='09/10/2017'>
# 00d0844880238.csv <re.Match object; span=(213, 224), match='24 MAR 2018'>
# 00d0845867211.csv <re.Match object; span=(1381, 1391), match='04/05/2017'>
# 00d0849102191.csv <re.Match object; span=(243, 254), match='27 MAY 2018'>
# 00d0854345015.csv <re.Match object; span=(968, 978), match='11/08/2017'>
# 00d0855903342.csv <re.Match object; span=(1114, 1122), match='17-02-18'>
# 00d0859215539.csv <re.Match object; span=(1104, 1112), match='19-03-18'>
# 00d0859401532.csv <re.Match object; span=(870, 880), match='15-06-2018'>
# 00d0859698635.csv <re.Match object; span=(1248, 1258), match='30/08/2017'>
# 00d0862918541.csv <re.Match object; span=(1280, 1290), match='30-04-2018'>
# 00d0863890590.csv <re.Match object; span=(1070, 1080), match='11/03/2018'>
# 00d0864219792.csv <re.Match object; span=(1453, 1463), match='30/04/2017'>
# 00d0864913249.csv <re.Match object; span=(646, 656), match='23-06-2018'>
# 00d0868680143.csv <re.Match object; span=(622, 630), match='19/06/17'>
# 00d0870184164.csv <re.Match object; span=(486, 497), match='09 JUN 2018'>
# 00d0871332887.csv <re.Match object; span=(1447, 1457), match='17/03/2018'>
# 00d0876488640.csv <re.Match object; span=(902, 910), match='14-21-32'>
# 00d0876837917.csv None
# 00d0876844472.csv <re.Match object; span=(234, 245), match='09 MAY 2018'>
# 00d0877220068.csv <re.Match object; span=(1122, 1132), match='15/10/2017'>
# 00d0879733105.csv <re.Match object; span=(1741, 1751), match='29/07/2016'>
# 00d0880901672.csv <re.Match object; span=(240, 251), match='19 APR 2018'>
# 00d0881334709.csv <re.Match object; span=(1078, 1088), match='18/01/2018'>
# 00d0884773399.csv <re.Match object; span=(216, 227), match='27 MAR 2018'>
# 00d0885837043.csv <re.Match object; span=(929, 937), match='18/02/22'>
# 00d0886341707.csv <re.Match object; span=(878, 888), match='26/05/2018'>
# 00d0887482293.csv <re.Match object; span=(1131, 1141), match='05/10/2017'>
# 00d0889453684.csv <re.Match object; span=(609, 617), match='11/03/18'>
# 00d0890929577.csv <re.Match object; span=(3977, 3987), match='20/04/2018'>
# 00d0891802782.csv <re.Match object; span=(816, 826), match='12-11-2017'>
# 00d0892499515.csv <re.Match object; span=(928, 936), match='01-03-18'>
# 00d0892818805.csv <re.Match object; span=(1014, 1024), match='11/09/2017'>
# 00d0898762404.csv <re.Match object; span=(1411, 1421), match='23/05/2018'>
# 00d0898930568.csv <re.Match object; span=(1104, 1112), match='24-01-18'>
# 00d0901837324.csv <re.Match object; span=(225, 232), match=' DECO\n2'>
# 00d0902251681.csv <re.Match object; span=(580, 588), match='27/06/18'>
# 00d0902256238.csv <re.Match object; span=(646, 656), match='02-04-2018'>
# 00d0904732199.csv <re.Match object; span=(565, 575), match='00-88-6555'>
# 00d0904741091.csv <re.Match object; span=(237, 248), match='13 MAY 2018'>
# 00d0910574175.csv <re.Match object; span=(701, 711), match='24/05/2018'>
# 00d0910676977.csv <re.Match object; span=(951, 961), match='30/03/2018'>
# 00d0910776987.csv <re.Match object; span=(1104, 1112), match='03-05-18'>
# 00d0911031443.csv <re.Match object; span=(354, 361), match='10/10\n3'>
# 00d0911267818.csv <re.Match object; span=(2399, 2407), match='07-06-16'>
# 00d0913770897.csv <re.Match object; span=(1146, 1156), match='12/02/2018'>
# 00d0914854329.csv <re.Match object; span=(210, 221), match='14 MAR 2018'>
# 00d0916006350.csv <re.Match object; span=(869, 879), match='24/06/2018'>
# 00d0916574976.csv <re.Match object; span=(733, 741), match='22-52-62'>
# 00d0920231897.csv <re.Match object; span=(4483, 4493), match='19/07/2017'>
# 00d0920899195.csv None
# 00d0921867955.csv <re.Match object; span=(2361, 2368), match='21-31/2'>
# 00d0922342206.csv <re.Match object; span=(644, 654), match='04/03/2018'>
# 00d0923796657.csv <re.Match object; span=(869, 879), match='30/03/2017'>
# 00d0924594862.csv <re.Match object; span=(2275, 2282), match='MARY\n29'>
# 00d0928366034.csv <re.Match object; span=(1069, 1077), match='16/05/01'>
# 00d0928411057.csv <re.Match object; span=(170, 177), match=' MART\n1'>
# 00d0929882897.csv <re.Match object; span=(1131, 1141), match='17/09/2017'>
# 00d0930697230.csv <re.Match object; span=(826, 831), match='JAN\n9'>
# 00d0935614053.csv <re.Match object; span=(573, 583), match='27/03/2018'>
# 00d0935702550.csv <re.Match object; span=(608, 618), match='20/03/2018'>
# 00d0942116852.csv <re.Match object; span=(572, 582), match='14-01-2018'>
# 00d0944155034.csv <re.Match object; span=(646, 656), match='04-06-2018'>
# 00d0944630849.csv <re.Match object; span=(850, 860), match='23/03/2018'>
# 00d0945045450.csv <re.Match object; span=(1059, 1069), match='21-04-2018'>
# 00d0945445352.csv <re.Match object; span=(2525, 2533), match='25-03-18'>
# 00d0948483091.csv <re.Match object; span=(642, 649), match='21-31/2'>
# 00d0948775947.csv <re.Match object; span=(244, 250), match='MART\n2'>
# 00d0950145735.csv <re.Match object; span=(870, 880), match='05-06-2018'>
# 00d0950629356.csv <re.Match object; span=(699, 707), match='12/05/18'>
# 00d0951021760.csv None
# 00d0952509602.csv <re.Match object; span=(4567, 4575), match='04/03/18'>
# 00d0953772440.csv <re.Match object; span=(1501, 1511), match='15/05/2017'>
# 00d0954032591.csv <re.Match object; span=(213, 224), match='29 MAR 2018'>
# 00d0955195431.csv <re.Match object; span=(1248, 1258), match='16/09/2017'>
# 00d0958758313.csv <re.Match object; span=(3019, 3026), match='MARY\n35'>
# 00d0961798581.csv <re.Match object; span=(3523, 3530), match='MARY\n41'>
# 00d0963161084.csv <re.Match object; span=(6094, 6104), match='23/04/2017'>
# 00d0964499840.csv <re.Match object; span=(1300, 1310), match='18/01/2018'>
# 00d0965540723.csv <re.Match object; span=(3587, 3595), match='25-04-18'>
# 00d0968376605.csv <re.Match object; span=(5839, 5849), match='12/13/2016'>
# 00d0969391958.csv <re.Match object; span=(744, 755), match='05-AUG-2017'>
# 00d0970540567.csv <re.Match object; span=(213, 224), match='12 MAR 2018'>
# 00d0972867846.csv <re.Match object; span=(1037, 1047), match='24-05-2018'>
# 00d0973066652.csv <re.Match object; span=(1165, 1175), match='11/01/2019'>
# 00d0973462000.csv <re.Match object; span=(5295, 5305), match='01/11/2017'>
# 00d0975647472.csv <re.Match object; span=(1131, 1141), match='23/10/2017'>
# 00d0976342068.csv <re.Match object; span=(3031, 3039), match='26/02/18'>
# 00d0976572552.csv None
# 00d0976607312.csv <re.Match object; span=(1104, 1112), match='20-02-18'>
# 00d0977582300.csv <re.Match object; span=(3266, 3276), match='09/02/2018'>
# 00d0978814485.csv None
# 00d0979473699.csv <re.Match object; span=(768, 776), match='28/05/18'>
# 00d0981184214.csv <re.Match object; span=(737, 747), match='30-04-2018'>
# 00d0981274700.csv <re.Match object; span=(615, 623), match='12/01/18'>
# 00d0982931302.csv <re.Match object; span=(5179, 5189), match='18/09/2017'>
# 00d0986033233.csv <re.Match object; span=(799, 809), match='11/01/2018'>
# 00d0989196649.csv <re.Match object; span=(799, 809), match='02/01/2018'>
# 00d0989858817.csv <re.Match object; span=(1104, 1112), match='21-11-16'>
# 00d0992127574.csv <re.Match object; span=(913, 923), match='10/04/2017'>
# 00d0992954979.csv <re.Match object; span=(237, 248), match='14 MAY 2018'>
# 00d0992959314.csv <re.Match object; span=(1133, 1143), match='21/03/2018'>
# 00d0997573916.csv <re.Match object; span=(667, 678), match='15/APR/2017'>
# 00d0999793595.csv <re.Match object; span=(240, 251), match='20 JUN 2018'>
# 00d0999799045.csv <re.Match object; span=(5179, 5189), match='26/11/2017'>

# %%
trial_re = '(\d{1,2})?[,\s/-](Jan|JAN|Feb|FEB|Mar|MAR|Apr|APR|May|MAY|Jun|JUN|Jul|JUL|Aug|AUG|Sep|SEP|Oct|OCT|Nov|NOV|Dec|DEC)'
test = '(\d{1,2})?[,\s/-](Jan|JAN|Feb|FEB|Mar|MAR|Apr|APR|May|MAY|Jun|JUN|Jul|JUL|Aug|AUG|Sep|SEP|Oct|OCT|Nov|NOV|Dec|DEC)[a-zA-Z.,-]*[,\s/-]\d+'
dates = re.search(test, OCR_STRING)
# dates = re.findall(test, OCR_STRING)
print(dates.group())
# print(type(dates.group()))
# Out:
# 11 JUN 2018
